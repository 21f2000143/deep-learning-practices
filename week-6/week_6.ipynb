# %% [markdown]
# # **INSTALLING MODULES**

# %%
# !pip install speechbrain==0.5.16
# !pip install faster_whisper
# !pip install pyannote.audio
# !pip install whisper
# Out:
# Collecting speechbrain==0.5.16
#   Using cached speechbrain-0.5.16-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: hyperpyyaml in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain==0.5.16) (1.2.2)
# Requirement already satisfied: joblib in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain==0.5.16) (1.5.1)
# Requirement already satisfied: numpy in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain==0.5.16) (1.26.4)
# Requirement already satisfied: packaging in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain==0.5.16) (25.0)
# Requirement already satisfied: scipy in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain==0.5.16) (1.15.3)
# Requirement already satisfied: sentencepiece in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain==0.5.16) (0.2.0)
# Requirement already satisfied: torch>=1.9 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain==0.5.16) (2.7.1)
# Requirement already satisfied: torchaudio in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain==0.5.16) (2.7.1)
# Requirement already satisfied: tqdm in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain==0.5.16) (4.67.1)
# Requirement already satisfied: huggingface-hub in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain==0.5.16) (0.33.2)
# Requirement already satisfied: filelock in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (1.14.0)
# Requirement already satisfied: networkx in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (3.4.2)
# Requirement already satisfied: jinja2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (3.1.6)
# Requirement already satisfied: fsspec in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=1.9->speechbrain==0.5.16) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from triton==3.3.1->torch>=1.9->speechbrain==0.5.16) (65.6.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.9->speechbrain==0.5.16) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub->speechbrain==0.5.16) (6.0.2)
# Requirement already satisfied: requests in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub->speechbrain==0.5.16) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub->speechbrain==0.5.16) (1.1.5)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from hyperpyyaml->speechbrain==0.5.16) (0.18.14)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain==0.5.16) (0.2.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from jinja2->torch>=1.9->speechbrain==0.5.16) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from requests->huggingface-hub->speechbrain==0.5.16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from requests->huggingface-hub->speechbrain==0.5.16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from requests->huggingface-hub->speechbrain==0.5.16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from requests->huggingface-hub->speechbrain==0.5.16) (2025.6.15)
# Using cached speechbrain-0.5.16-py3-none-any.whl (630 kB)
# Installing collected packages: speechbrain
#   Attempting uninstall: speechbrain
#     Found existing installation: speechbrain 1.0.3
#     Uninstalling speechbrain-1.0.3:
#       Successfully uninstalled speechbrain-1.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyannote-audio 3.3.2 requires speechbrain>=1.0.0, but you have speechbrain 0.5.16 which is incompatible.
# Successfully installed speechbrain-0.5.16
# Requirement already satisfied: faster_whisper in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: ctranslate2<5,>=4.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from faster_whisper) (4.6.0)
# Requirement already satisfied: huggingface-hub>=0.13 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from faster_whisper) (0.33.2)
# Requirement already satisfied: tokenizers<1,>=0.13 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from faster_whisper) (0.21.2)
# Requirement already satisfied: onnxruntime<2,>=1.14 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from faster_whisper) (1.22.1)
# Requirement already satisfied: av>=11 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from faster_whisper) (15.0.0)
# Requirement already satisfied: tqdm in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from faster_whisper) (4.67.1)
# Requirement already satisfied: setuptools in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from ctranslate2<5,>=4.0->faster_whisper) (65.6.3)
# Requirement already satisfied: numpy in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from ctranslate2<5,>=4.0->faster_whisper) (1.26.4)
# Requirement already satisfied: pyyaml<7,>=5.3 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from ctranslate2<5,>=4.0->faster_whisper) (6.0.2)
# Requirement already satisfied: coloredlogs in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from onnxruntime<2,>=1.14->faster_whisper) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from onnxruntime<2,>=1.14->faster_whisper) (25.2.10)
# Requirement already satisfied: packaging in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from onnxruntime<2,>=1.14->faster_whisper) (25.0)
# Requirement already satisfied: protobuf in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from onnxruntime<2,>=1.14->faster_whisper) (3.20.3)
# Requirement already satisfied: sympy in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from onnxruntime<2,>=1.14->faster_whisper) (1.14.0)
# Requirement already satisfied: filelock in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub>=0.13->faster_whisper) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub>=0.13->faster_whisper) (2025.3.0)
# Requirement already satisfied: requests in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub>=0.13->faster_whisper) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub>=0.13->faster_whisper) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub>=0.13->faster_whisper) (1.1.5)
# Requirement already satisfied: humanfriendly>=9.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from coloredlogs->onnxruntime<2,>=1.14->faster_whisper) (10.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from requests->huggingface-hub>=0.13->faster_whisper) (2025.6.15)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from sympy->onnxruntime<2,>=1.14->faster_whisper) (1.3.0)
# Requirement already satisfied: pyannote.audio in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (3.3.2)
# Requirement already satisfied: asteroid-filterbanks>=0.4 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (0.4.0)
# Requirement already satisfied: einops>=0.6.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (0.8.1)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (0.33.2)
# Requirement already satisfied: lightning>=2.0.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (2.5.2)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (2.3.0)
# Requirement already satisfied: pyannote.core>=5.0.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (5.0.0)
# Requirement already satisfied: pyannote.database>=5.0.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (5.1.3)
# Requirement already satisfied: pyannote.metrics>=3.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (3.2.1)
# Requirement already satisfied: pyannote.pipeline>=3.0.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (3.0.1)
# Requirement already satisfied: pytorch-metric-learning>=2.1.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (2.8.1)
# Requirement already satisfied: rich>=12.0.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (14.0.0)
# Requirement already satisfied: semver>=3.0.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (3.0.4)
# Requirement already satisfied: soundfile>=0.12.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (0.13.1)
# Collecting speechbrain>=1.0.0 (from pyannote.audio)
#   Using cached speechbrain-1.0.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: tensorboardX>=2.6 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (2.6.4)
# Requirement already satisfied: torch>=2.0.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (2.7.1)
# Requirement already satisfied: torch-audiomentations>=0.11.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (0.12.0)
# Requirement already satisfied: torchaudio>=2.2.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (2.7.1)
# Requirement already satisfied: torchmetrics>=0.11.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.audio) (1.7.4)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from omegaconf<3.0,>=2.1->pyannote.audio) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from omegaconf<3.0,>=2.1->pyannote.audio) (6.0.2)
# Requirement already satisfied: numpy in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from asteroid-filterbanks>=0.4->pyannote.audio) (1.26.4)
# Requirement already satisfied: typing-extensions in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from asteroid-filterbanks>=0.4->pyannote.audio) (4.14.1)
# Requirement already satisfied: filelock in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (25.0)
# Requirement already satisfied: requests in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from huggingface-hub>=0.13.0->pyannote.audio) (1.1.5)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio) (0.14.3)
# Requirement already satisfied: pytorch-lightning in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from lightning>=2.0.1->pyannote.audio) (2.5.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (3.8.4)
# Requirement already satisfied: setuptools in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning>=2.0.1->pyannote.audio) (65.6.3)
# Requirement already satisfied: sympy>=1.13.3 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (1.14.0)
# Requirement already satisfied: networkx in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (3.4.2)
# Requirement already satisfied: jinja2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch>=2.0.0->pyannote.audio) (3.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (3.4.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (1.3.1)
# Requirement already satisfied: idna>=2.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.0.1->pyannote.audio) (3.10)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.core>=5.0.0->pyannote.audio) (2.4.0)
# Requirement already satisfied: scipy>=1.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.core>=5.0.0->pyannote.audio) (1.15.3)
# Requirement already satisfied: pandas>=0.19 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.database>=5.0.1->pyannote.audio) (2.2.3)
# Requirement already satisfied: typer>=0.12.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.database>=5.0.1->pyannote.audio) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (2025.2)
# Requirement already satisfied: scikit-learn>=0.17.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.metrics>=3.2->pyannote.audio) (1.7.0)
# Requirement already satisfied: docopt>=0.6.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.metrics>=3.2->pyannote.audio) (0.6.2)
# Requirement already satisfied: tabulate>=0.7.7 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.metrics>=3.2->pyannote.audio) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.metrics>=3.2->pyannote.audio) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote.audio) (3.0.9)
# Requirement already satisfied: optuna>=3.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from pyannote.pipeline>=3.0.1->pyannote.audio) (4.4.0)
# Requirement already satisfied: alembic>=1.5.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (1.16.4)
# Requirement already satisfied: colorlog in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (2.0.41)
# Requirement already satisfied: Mako in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (1.3.10)
# Requirement already satisfied: tomli in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (2.2.1)
# Requirement already satisfied: six>=1.5 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pyannote.database>=5.0.1->pyannote.audio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from rich>=12.0.0->pyannote.audio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from rich>=12.0.0->pyannote.audio) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->pyannote.audio) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote.audio) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote.audio) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from soundfile>=0.12.1->pyannote.audio) (1.15.0)
# Requirement already satisfied: pycparser in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote.audio) (2.21)
# Requirement already satisfied: hyperpyyaml in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain>=1.0.0->pyannote.audio) (1.2.2)
# Requirement already satisfied: sentencepiece in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from speechbrain>=1.0.0->pyannote.audio) (0.2.0)
# Requirement already satisfied: greenlet>=1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from sqlalchemy>=1.4.2->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote.audio) (3.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.0.0->pyannote.audio) (1.3.0)
# Requirement already satisfied: protobuf>=3.20 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from tensorboardX>=2.6->pyannote.audio) (3.20.3)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch-audiomentations>=0.11.0->pyannote.audio) (0.2.7)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch-audiomentations>=0.11.0->pyannote.audio) (1.2.5)
# Requirement already satisfied: primePy>=1.3 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote.audio) (1.3)
# Requirement already satisfied: click>=8.0.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote.audio) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote.audio) (1.5.4)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from hyperpyyaml->speechbrain>=1.0.0->pyannote.audio) (0.18.14)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain>=1.0.0->pyannote.audio) (0.2.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->pyannote.audio) (3.0.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from requests->huggingface-hub>=0.13.0->pyannote.audio) (2025.6.15)
# Using cached speechbrain-1.0.3-py3-none-any.whl (864 kB)
# Installing collected packages: speechbrain
#   Attempting uninstall: speechbrain
#     Found existing installation: speechbrain 0.5.16
#     Uninstalling speechbrain-0.5.16:
#       Successfully uninstalled speechbrain-0.5.16
# Successfully installed speechbrain-1.0.3
# Requirement already satisfied: whisper in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (1.1.10)
# Requirement already satisfied: six in /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages (from whisper) (1.17.0)

# %%
from huggingface_hub import login
from dotenv import load_dotenv
import os
load_dotenv()  # Automatically loads .env file from current directory
login(token=os.getenv("HUGGINGFACE_HUB_TOKEN"))

# %% [markdown]
# # **IMPORT NECESSARY LIBRARIES**

# %%
import librosa
import traceback
from faster_whisper import WhisperModel
import torch
import whisper
import datetime
from pathlib import Path
import pandas as pd
import re
import time
import os
import numpy as np
from sklearn.cluster import AgglomerativeClustering, KMeans
from pyannote.audio.pipelines.speaker_verification import PretrainedSpeakerEmbedding
from pyannote.audio import Audio
from pyannote.core import Segment
import speechbrain
from scipy.spatial.distance import cdist
from sklearn.metrics.pairwise import cosine_similarity

# %%
# !tar -xvf wavs.tar.gz

# %% [markdown]
# # **Defining Helper Functions**

# %%
# Purpose: This function is for converting time in seconds into a human-readable format,
# specifically  'hh:mm:ss'
# Input: It takes a floating-point number representing time in seconds
# Output: It should return a string representing the time in 'hh:mm:ss'
def convert_time(secs):
  return datetime.timedelta(seconds=round(secs))

# %%
# Purpose: This function handles the audio transcription process using the
# Output: Return a list of segment dictionaries.
def transcribe_audio(audio_file, model_name="base", language="en", beam_size=5, best_of=5):
  # Load the model
  model = WhisperModel(model_name, compute_type='int8')

  try:
    # Transcribe audio
    options = dict(language='en', beam_size=5, best_of=5)
    transcribe_options = dict(task='transcribe', **options)
    segments_raw, info = model.transcribe(audio_file, **transcribe_options)

    # Convert back to original openai format
    segments = []
    for segment_chunk in segments_raw:
      chunk = {}
      chunk['start'] = segment_chunk.start
      chunk['end'] = segment_chunk.end
      chunk['text'] = segment_chunk.text
      segments.append(chunk)

  except Exception as e:
    raise RuntimeError(f"Error converting audio to transcribe.{e}")

  return segments

# %%
# Purpose: This function extracts a speaker embedding for a specific segment of
# an audio file using a pre-trained speaker embedding model.
def extract_segment_embedding(audio_file, segment, total_duration,
                              embedding_model):
  try:
    audio = Audio()
    start = segment['start']
    end = min(total_duration, segment['end']) # end time cannot more than t_d

    clip = Segment(start, end)
    # method to extract the waveform for the given segment from the
    waveform, sample_rate = audio.crop(audio_file, clip)

    embeddings = embedding_model(waveform[None])

    return embeddings.squeeze()
  except Exception as e:
    traceback.print_exc()
    raise RuntimeError(f"Error during segment embedding {e}")

# %%
def compute_segment_embeddings(audio_file, segments, embedding_model):
  audio_data, sample_rate = librosa.load(audio_file, mono=True, sr=16000)
  total_duration = len(audio_data)/sample_rate

  # get embeddings for each segments
  embeddings = []
  for segment in segments:
    embeddings.append(extract_segment_embedding(audio_file, segment, total_duration, embedding_model))
  
  embedding_vec = np.stack(embeddings)
  embedding_vec = np.nan_to_num(embedding_vec)

  return embedding_vec

# %%
def cluster_embeddings(embeddings, n_clusters):
  # Initialize KMeans cluster
  kmeans = KMeans(
      n_clusters=n_clusters,
      random_state=42
  )

  kmeans.fit(embeddings)
  labels = kmeans.labels_

  centroids = kmeans.cluster_centers_

  return labels, centroids

# %%
# Purpose: Calculate the average embedding for each cluster. This average embedding represents a 
# cluster's speaker profile.
def compute_cluster_averages(embeddings, labels, n_clusters):
  avg_cluster_labels = {}
  for i in range(n_clusters):
    cluster_masked = (labels==i)
    masked_embeddings = embeddings[cluster_masked]
    avg_embedding = np.mean(masked_embeddings, axis=0)
    avg_cluster_labels[i]=avg_embedding
  return avg_cluster_labels

# %%
# Purpose: To load audio files of known speakers, compute their speaker embeddings, and store them for speaker identification.
def load_known_speaker_embeddings(known_speaker_files, embedding_model):
  known_speaker = {}
  for f_name in known_speaker_files:
    audio_data, sample_rate = librosa.load(f_name, mono=True, sr=16000)
    audio = Audio()
    total_duration = len(audio_data)/sample_rate
    clip = Segment(0, total_duration)

    waveform, sample_rate = audio.crop(f_name, clip)

    embeddings = embedding_model(waveform[None])
    embeddings = embeddings.squeeze()
    known_speaker[f_name.split('.')[0]]=embeddings
  
  return known_speaker

# %%
def assign_speaker_labels(cluster_avg_embeddings, known_speaker_embeddings, similarity_threshold=0.7):
  speaker_labels = {}
  for spk_label, spk_emb in known_speaker_embeddings.items():
    max_siml = -1
    corr_label = 'Unknown'
    for cluster_id, avg_emb in cluster_avg_embeddings.items():
      # Calculate cosine similarity
      # Reshape the 1D arrays to 2D arrays
      cos_siml = cosine_similarity(avg_emb.reshape(1, -1), spk_emb.reshape(1, -1))[0][0]
      if cos_siml>max_siml:
        max_siml = cos_siml
        corr_label = spk_label

    # Check the threshold
    if max_siml> similarity_threshold:
      speaker_labels[cluster_id]=corr_label
    else:
      speaker_labels[cluster_id]=corr_label
  return speaker_labels

# %%
# Purpose: This function orchestrates the entire speaker diarization and identification pipeline, calling all the previously defined functions in the correct sequence.
def run_pipeline(audio_file, embedding_model, known_speaker_embeddings, n_clusters=3, whisper_model_name="base", similarity_threshold=0.7):
  print('#'*40)
  print("Started Diarization and Identification Pipeline")
  # Get the segments of the audio
  segments = transcribe_audio(audio_file)
  # Get the segments vector
  embedding_vec = compute_segment_embeddings(audio_file, segments, embedding_model)
  # Get the labels and centroids for each cluster
  labels, centroids = cluster_embeddings(embedding_vec, n_clusters)
  # Computer cluster avetages
  cluster_avg_embeddings = compute_cluster_averages(embedding_vec, labels, n_clusters)
  # Get the labels for the speakers in the cluster
  speaker_labels = assign_speaker_labels(cluster_avg_embeddings, known_speaker_embeddings, similarity_threshold)

  # Annotate each segment with its cluster ID and assigned speaker ID.
  results = []
  for segment, cluster_id in zip(segments, labels):
      start = segment['start']
      end = segment['end']
      speaker_id = speaker_labels.get(cluster_id)
      results.append({
          'Start': convert_time(start),
          'End': convert_time(end),
          'Test': segment['text'],
          'Cluster': cluster_id,
          'Speaker_ID': speaker_id
      })
  
  df = pd.DataFrame(results)
  print(df)
  return df, len(segments), centroids

# %%
embedding_model = PretrainedSpeakerEmbedding(
    "speechbrain/spkrec-ecapa-voxceleb",
    device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
)
# Out:
# /home/sachin/miniconda3/envs/lmlf/lib/python3.10/site-packages/speechbrain/utils/autocast.py:188: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   wrapped_fwd = torch.cuda.amp.custom_fwd(fwd, cast_inputs=cast_inputs)

# %%
known_speaker_files = ['sample.wav', 'sample_noisy.wav', 'speaker_A.wav', 'speaker_B.wav', 'speaker_C.wav', 'speaker_D.wav', 'speaker_E.wav']

# %%
known_speakers = load_known_speaker_embeddings(known_speaker_files, embedding_model)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
clean_audio = 'sample.wav'
df_clean, n_segments_clean, centroids_clean = run_pipeline(clean_audio, embedding_model, known_speakers, 3, 'base', 0.7)
# Out:
# ########################################
# Started Diarization and Identification Pipeline

# %%
df_clean.head(10)

# %%
noisy_audio = 'sample_noisy.wav'
df_noisy, n_segments_noisy, centroids_noisy = run_pipeline(noisy_audio, embedding_model, known_speakers, 3, 'base', 0.7)

# %%
df_noisy.head(10)
